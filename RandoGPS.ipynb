# %%
# %run xIpyLeafLet1.py
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# Cartes disponibles :
# 0 :  OpenStreetMap
# 1 :  TopoMap
# 2 :  HikeBike
# 3 :  MtbMap
# Carte: rang ? (0 par défaut) :0
# carte: OpenStreetMap
# 0 :  ./2020-05-06_12-59-27.gpx
# 1 :  ./2020-05-05_14-30-13.gpx
# 2 :  ./2020-05-04_14-23-26.gpx
# 3 :  ./2020-05-03_14-31-08.gpx
# 4 :  ./2020-04-29_13-47-10.gpx
# 5 :  ./2020-04-28_13-27-38.gpx
# Fichier.gpx: rang ? 1
#
# Heure de début :  le 05 05 2020 à 14 heures 30 minutes 16 secondes.
# Heure de fin : le 05 05 2020 à 15 heures 29 minutes 48 secondes.
#
# Distance totale parcourue : 4937.275470612278 mêtres.
# montée :    147.21 , descente :   149.20 (mêtres).
# Vitesse moyenne :     4.98 km/h.
#   <div class="bk-root" id="5de894ee-d5bd-4686-8cd8-2a496a6483a4" data-root-id="1116"></div>
# ...
